# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("churn.csv")

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
data.shape
# Out:
# (7043, 21)

# %%
data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
X = data.drop('Churn', axis = 1)
y = data['Churn']

# %%
dropCols = ['customerID']
X.drop(dropCols, axis = 1, inplace = True)

# %%
catCol = []
for i in X.columns:
    if X[i].dtype == 'object':
        catCol.append(i)
catCol
# Out:
# ['gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'TotalCharges']

# %%
X['TotalCharges'].value_counts()
# Out:
#           11
# 20.2      11
# 19.75      9
# 20.05      8
# 19.9       8
#           ..
# 6849.4     1
# 692.35     1
# 130.15     1
# 3211.9     1
# 6844.5     1
# Name: TotalCharges, Length: 6531, dtype: int64

# %%
pd.f
# Out:
# 0.1561834445548772

# %%
# s = 0
# n = 0
totalCharges = []
idx = 0
errors = []
for i in X['TotalCharges']:
    try:
        totalCharges.append(float(i))
#         s = s + float(i)
#         n += 1
    except:
        errors.append(idx)
    idx = idx + 1

# %%
errors
# Out:
# [488, 753, 936, 1082, 1340, 3331, 3826, 4380, 5218, 6670, 6754]

# %%
XNew = X.drop(errors, axis = 0)

# %%
totalCharges
# Out:
# [29.85,
#  1889.5,
#  108.15,
#  1840.75,
#  151.65,
#  820.5,
#  1949.4,
#  301.9,
#  3046.05,
#  3487.95,
#  587.45,
#  326.8,
#  5681.1,
#  5036.3,
#  2686.05,
#  7895.15,
#  1022.95,
#  7382.25,
#  528.35,
#  1862.9,
#  39.65,
#  202.25,
#  20.15,
#  3505.1,
#  2970.3,
#  1530.6,
#  4749.15,
#  30.2,
#  6369.45,
#  1093.1,
#  6766.95,
#  181.65,
#  1874.45,
#  20.2,
#  45.25,
#  7251.7,
#  316.9,
#  3548.3,
#  3549.25,
#  1105.4,
#  475.7,
#  4872.35,
#  418.25,
#  4861.45,
#  981.45,
#  3906.7,
#  97.0,
#  144.15,
#  4217.8,
#  4254.1,
#  3838.75,
#  1426.4,
#  1752.65,
#  633.3,
#  4456.35,
#  1752.55,
#  6311.2,
#  7076.35,
#  894.3,
#  7853.7,
#  4707.1,
#  5450.7,
#  2962.0,
#  957.1,
#  857.25,
#  244.1,
#  3650.35,
#  2497.2,
#  930.9,
#  887.35,
#  49.05,
#  1090.65,
#  7099.0,
#  1424.6,
#  177.4,
#  6139.5,
#  2688.85,
#  482.25,
#  2111.3,
#  1216.6,
#  79.35,
#  565.35,
#  496.9,
#  4327.5,
#  973.35,
#  918.75,
#  2215.45,
#  1057.0,
#  927.1,
#  1009.25,
#  2570.2,
# ...

# %%
XNew.shape
# Out:
# (7032, 19)

# %%
len(totalCharges)
# Out:
# 7032

# %%
XNew['TotalCharges'] = totalCharges

# %%
XNew['TotalCharges']
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7032, dtype: float64

# %%
y = y.replace({'Yes': 1, 'No' : 0})

# %%
y.shape
# Out:
# (7043,)

# %%
yNew = y.drop(errors, axis = 0)

# %%
yNew.shape
# Out:
# (7032,)

# %%
XNew.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
XFinal = pd.get_dummies(XNew, drop_first=True)

# %%
#Normalization
#val - val.mean() / val.std()
# Out:
# /var/folders/7l/_1tqf3ys5d56lzcftggq3nbr0000gn/T/ipykernel_2639/3445102205.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   XNew.std()
# SeniorCitizen        0.368844
# tenure              24.545260
# MonthlyCharges      30.085974
# TotalCharges      2266.771362
# labels               0.441782
# dtype: float64

# %%
XFinal.describe().T
# Out:
#                                         count         mean          std  \
# SeniorCitizen                          7032.0     0.162400     0.368844
# tenure                                 7032.0    32.421786    24.545260
# MonthlyCharges                         7032.0    64.798208    30.085974
# TotalCharges                           7032.0  2283.300441  2266.771362
# gender_Male                            7032.0     0.504693     0.500014
# Partner_Yes                            7032.0     0.482509     0.499729
# Dependents_Yes                         7032.0     0.298493     0.457629
# PhoneService_Yes                       7032.0     0.903299     0.295571
# MultipleLines_No phone service         7032.0     0.096701     0.295571
# MultipleLines_Yes                      7032.0     0.421928     0.493902
# InternetService_Fiber optic            7032.0     0.440273     0.496455
# InternetService_No                     7032.0     0.216155     0.411650
# ...

# %%
XFinal = (XFinal - XFinal.mean()) / XFinal.std() #Normalization

# %%
XFinal['labels'] = yNew

# %%
corrMat = XFinal.corr()

# %%
corrMat = corrMat['labels'].sort_values(ascending = False)

# %%
corrMat.items
# Out:
# <bound method Series.items of labels                                   1.000000
# InternetService_Fiber optic              0.307463
# PaymentMethod_Electronic check           0.301455
# MonthlyCharges                           0.192858
# PaperlessBilling_Yes                     0.191454
# SeniorCitizen                            0.150541
# StreamingTV_Yes                          0.063254
# StreamingMovies_Yes                      0.060860
# MultipleLines_Yes                        0.040033
# PhoneService_Yes                         0.011691
# gender_Male                             -0.008545
# MultipleLines_No phone service          -0.011691
# DeviceProtection_Yes                    -0.066193
# OnlineBackup_Yes                        -0.082307
# PaymentMethod_Mailed check              -0.090773
# PaymentMethod_Credit card (automatic)   -0.134687
# Partner_Yes                             -0.149982
# Dependents_Yes                          -0.163128
# ...

# %%
dropCols = ['labels']
for i, v in corrMat.items():
    if abs(v) < 0.1:
        dropCols.append(i)
dropCols
# Out:
# ['labels',
#  'StreamingTV_Yes',
#  'StreamingMovies_Yes',
#  'MultipleLines_Yes',
#  'PhoneService_Yes',
#  'gender_Male',
#  'MultipleLines_No phone service',
#  'DeviceProtection_Yes',
#  'OnlineBackup_Yes',
#  'PaymentMethod_Mailed check']

# %%
XFinal.drop(dropCols, axis = 1, inplace = True)

# %%
X_train, X_val, y_train, y_val = train_test_split(XFinal, yNew, test_size = 0.2, random_state = 1)

# %%
X_train.head()
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges  Partner_Yes  \
# 3457      -0.440296 -1.280157       -1.505625     -0.998689    -0.965539
# 612       -0.440296  1.368012       -1.470725     -0.408599    -0.965539
# 589       -0.440296  1.571717        0.850954      1.934359     1.035543
# 2685      -0.440296  1.612459        1.191645      2.228169     1.035543
# 1549      -0.440296 -1.280157       -0.629802     -0.987065    -0.965539
#
#       Dependents_Yes  InternetService_Fiber optic  InternetService_No  \
# 3457       -0.652259                    -0.886833            1.904153
# 612         1.532916                    -0.886833            1.904153
# 589         1.532916                    -0.886833           -0.525093
# 2685       -0.652259                     1.127447           -0.525093
# 1549       -0.652259                    -0.886833           -0.525093
#
#       OnlineSecurity_No internet service  OnlineSecurity_Yes  ...  \
# ...

# %%
lr = LogisticRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import classification_report

# %%
#Actual testing
pred = lr.predict(X_val)

# %%
print(classification_report(pred, y_val))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.84      0.87      1107
#            1       0.52      0.63      0.57       300
#
#     accuracy                           0.80      1407
#    macro avg       0.70      0.74      0.72      1407
# weighted avg       0.81      0.80      0.80      1407

# %%
from sklearn.svm import SVC

# %%
svc = SVC()

# %%
svc.fit(X_train, y_train)
# Out:
# SVC()

# %%
pred = svc.predict(X_val)

# %%
print(classification_report(pred, y_val))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.83      0.87      1131
#            1       0.48      0.64      0.55       276
#
#     accuracy                           0.79      1407
#    macro avg       0.69      0.73      0.71      1407
# weighted avg       0.82      0.79      0.80      1407

# %%
X_val[pred == 1]
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges  Partner_Yes  \
# 5036       2.270878 -0.669041        0.683102     -0.400636     1.035543
# 1665      -0.440296 -0.954228        0.400578     -0.714563    -0.965539
# 927       -0.440296 -0.791264        0.543502     -0.587179    -0.965539
# 4648      -0.440296 -1.239416        0.182869     -0.943765    -0.965539
# 3735      -0.440296 -1.239416        0.639893     -0.948155     1.035543
# ...             ...       ...             ...           ...          ...
# 2069      -0.440296 -1.280157        1.023792     -0.965117    -0.965539
# 4639       2.270878 -0.261630        0.957316      0.053291    -0.965539
# 6912      -0.440296 -0.954228        0.688088     -0.658029    -0.965539
# 5023      -0.440296 -1.280157        0.182869     -0.976279    -0.965539
# 6288      -0.440296 -1.239416        0.486997     -0.943258    -0.965539
#
#       Dependents_Yes  InternetService_Fiber optic  InternetService_No  \
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
pred = rfc.predict(X_val)

# %%
print(classification_report(pred, y_val))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.82      0.86      1142
#            1       0.45      0.62      0.52       265
#
#     accuracy                           0.78      1407
#    macro avg       0.67      0.72      0.69      1407
# weighted avg       0.82      0.78      0.80      1407

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred = dt.predict(X_val)

# %%
print(classification_report(pred, y_val))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.81      0.81      1024
#            1       0.48      0.45      0.46       383
#
#     accuracy                           0.71      1407
#    macro avg       0.64      0.63      0.64      1407
# weighted avg       0.71      0.71      0.71      1407
